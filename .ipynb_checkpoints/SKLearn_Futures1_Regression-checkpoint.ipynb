# %%
# importing dependencies

import pandas as pd
import datetime as dt
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# reading CSV data

df = pd.read_csv('C:/Users/sweir/OneDrive/Desktop/Analysis Projects/Crude_Oil_Price_Projection/Resources/clean_datasets/Cleaned_Crude_Oil_Dataset.csv')
df.head()
# Out:
#        Date  U.S. Field Production of Crude Oil (1k Bar.)  \
# 0  Jan-1986                                        283248
# 1  Feb-1986                                        256855
# 2  Mar-1986                                        279413
# 3  Apr-1986                                        265917
# 4  May-1986                                        273964
#
#    Gross Inputs to Refineries (1k Bar./Day)  \
# 0                                     12583
# 1                                     12068
# 2                                     11759
# 3                                     12603
# 4                                     13314
#
#    Operable Crude Oil Distillation Capacity (1k Bar./Calendar Day)  \
# 0                                              15459
# 1                                              15485
# 2                                              15485
# 3                                              15473
# 4                                              15484
#
#    Operating Crude Oil Distillation Capacity (1k Bar./Day)  \
# 0                                              14639
# 1                                              14538
# 2                                              14517
# 3                                              14550
# 4                                              14805
#
#    Idle Crude Oil Distillation Capacity (1k Bar./Day)  \
# 0                                                820
# 1                                                947
# 2                                                968
# 3                                                923
# 4                                                679
#
#    Percent Utilization of Refinery Operable Capacity  \
# 0                                               81.4
# 1                                               77.9
# 2                                               75.9
# 3                                               81.5
# 4                                               86.0
#
#    Cushing, OK Crude Oil Future Contract 1 ($/Bar.)  \
# 0                                              23.0
# 1                                              15.5
# 2                                              12.6
# 3                                              12.8
# 4                                              15.3
#
#    Cushing, OK Crude Oil Future Contract 2 ($/Bar.)  \
# 0                                              22.4
# 1                                              15.7
# 2                                              13.0
# 3                                              12.6
# 4                                              14.8
#
#    Cushing, OK Crude Oil Future Contract 3 ($/Bar.)  \
# 0                                              21.9
# 1                                              15.8
# 2                                              13.1
# 3                                              12.6
# 4                                              14.4
#
#    Cushing, OK Crude Oil Future Contract 4 ($/Bar.)  \
# 0                                              21.7
# 1                                              15.9
# 2                                              13.3
# 3                                              12.6
# 4                                              14.3
#
#    Cushing, OK WTI Spot Price FOB ($/Bar.)
# 0                                     22.9
# 1                                     15.5
# 2                                     12.6
# 3                                     12.8
# 4                                     15.4

# %%
df.dtypes
# Out:
# Date                                                                object
# U.S. Field Production of Crude Oil (1k Bar.)                         int64
# Gross Inputs to Refineries (1k Bar./Day)                             int64
# Operable Crude Oil Distillation Capacity (1k Bar./Calendar Day)      int64
# Operating Crude Oil Distillation Capacity (1k Bar./Day)              int64
# Idle Crude Oil Distillation Capacity (1k Bar./Day)                   int64
# Percent Utilization of Refinery Operable Capacity                  float64
# Cushing, OK Crude Oil Future Contract 1 ($/Bar.)                   float64
# Cushing, OK Crude Oil Future Contract 2 ($/Bar.)                   float64
# Cushing, OK Crude Oil Future Contract 3 ($/Bar.)                   float64
# Cushing, OK Crude Oil Future Contract 4 ($/Bar.)                   float64
# Cushing, OK WTI Spot Price FOB ($/Bar.)                            float64
# dtype: object

# %%
# to convert the date column to type DATETIME
df['Date'] = pd.to_datetime(df['Date'])

# %%
# reformatting columns

df = df.rename(columns={'Cushing, OK Crude Oil Future Contract 1 ($/Bar.)': 'FuturesPrice1', 'Cushing, OK Crude Oil Future Contract 2 ($/Bar.)': 'FuturesPrice2', 'Cushing, OK Crude Oil Future Contract 3 ($/Bar.)': 'FuturesPrice3', 'Cushing, OK Crude Oil Future Contract 4 ($/Bar.)': 'FuturesPrice4'})
df.head()
# Out:
#         Date  U.S. Field Production of Crude Oil (1k Bar.)  \
# 0 1986-01-01                                        283248
# 1 1986-02-01                                        256855
# 2 1986-03-01                                        279413
# 3 1986-04-01                                        265917
# 4 1986-05-01                                        273964
#
#    Gross Inputs to Refineries (1k Bar./Day)  \
# 0                                     12583
# 1                                     12068
# 2                                     11759
# 3                                     12603
# 4                                     13314
#
#    Operable Crude Oil Distillation Capacity (1k Bar./Calendar Day)  \
# 0                                              15459
# 1                                              15485
# 2                                              15485
# 3                                              15473
# 4                                              15484
#
#    Operating Crude Oil Distillation Capacity (1k Bar./Day)  \
# 0                                              14639
# 1                                              14538
# 2                                              14517
# 3                                              14550
# 4                                              14805
#
#    Idle Crude Oil Distillation Capacity (1k Bar./Day)  \
# 0                                                820
# 1                                                947
# 2                                                968
# 3                                                923
# 4                                                679
#
#    Percent Utilization of Refinery Operable Capacity  FuturesPrice1  \
# 0                                               81.4           23.0
# 1                                               77.9           15.5
# 2                                               75.9           12.6
# 3                                               81.5           12.8
# 4                                               86.0           15.3
#
#    FuturesPrice2  FuturesPrice3  FuturesPrice4  \
# 0           22.4           21.9           21.7
# 1           15.7           15.8           15.9
# 2           13.0           13.1           13.3
# 3           12.6           12.6           12.6
# 4           14.8           14.4           14.3
#
#    Cushing, OK WTI Spot Price FOB ($/Bar.)
# 0                                     22.9
# 1                                     15.5
# 2                                     12.6
# 3                                     12.8
# 4                                     15.4

# %%
# initial visualization of Futures Price Data

plt.scatter(df.Date, df.FuturesPrice1)
plt.xlabel('Date')
plt.ylabel('WTI Futures Price(/bbl)')
plt.show()

# %%
# creating new dataframe with ONLY Date and Futures Pricing Data
futures_prices_df = df[['Date', 'FuturesPrice1']]
futures_prices_df.head()
# Out:
#         Date  FuturesPrice1
# 0 1986-01-01           23.0
# 1 1986-02-01           15.5
# 2 1986-03-01           12.6
# 3 1986-04-01           12.8
# 4 1986-05-01           15.3

# %%
 # setting the index for new DataFrame
futures_prices_df.set_index('Date')
# Out:
#             FuturesPrice1
# Date
# 1986-01-01           23.0
# 1986-02-01           15.5
# 1986-03-01           12.6
# 1986-04-01           12.8
# 1986-05-01           15.3
# ...                   ...
# 2021-06-01           71.4
# 2021-07-01           72.4
# 2021-08-01           67.7
# 2021-09-01           71.5
# 2021-10-01           81.2
#
# [430 rows x 1 columns]

# %%
# building a function for output of regression metrics
import sklearn.metrics as metrics
def regression_results(y_true, y_pred):
    Explained_Var=metrics.explained_variance_score(y_true, y_pred)
    Mean_Absolute_Error=metrics.mean_absolute_error(y_true, y_pred) 
    MSE=metrics.mean_squared_error(y_true, y_pred) 
    r2=metrics.r2_score(y_true, y_pred)
    print('Explained_Var: ', round(explained_variance,4))    
    print('r2: ', round(r2,4))
    print('MAE: ', round(Mean_Absolute_Error,4))
    print('MSE: ', round(MSE,4))
    print('RMSE: ', round(np.sqrt(mse),4))
